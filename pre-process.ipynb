# %%
import pandas as pd
import numpy as np
import os
from nltk.corpus import stopwords
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize

# %%
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#                                              summary            levels  \
# 0  Learn to branch your code's execution path by ...      ['beginner']
# 1  In this module, we show you how to use Narrato...  ['intermediate']
# 2  You'll be able to implement Azure Monitor for ...  ['intermediate']
# 3  Implement Windows Server IaaS VM network security  ['intermediate']
# 4  Learn how to recognize and synthesize speech b...  ['intermediate']
#
#                                             products  \
# 0                                         ['dotnet']
# 1                                        ['windows']
# 2  ['azure', 'azure-cloud-shell', 'azure-monitor'...
# 3  ['azure', 'azure-cloud-shell', 'azure-portal',...
# 4  ['azure', 'azure-cognitive-services', 'azure-s...
#
#                                                  uid    type  \
# 0              learn.languages.csharp-if-elseif-else  module
# 1             learn-windows.narrator-and-voice-input  module
# ...

# %%
# !pip install nltk
# import nltk
# nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\maleekha\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stop_words = set(stopwords.words('english')) 
def remove_stop_words(example_sent):
    word_tokens = example_sent.lower().split(' ')   
    filtered_sentence = [w for w in word_tokens if not w in stop_words]   
    filtered_sentence = []   
    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w)
    return ' '.join(filtered_sentence)

all_desc = data['title_and_summary'].values
all_pp = [remove_stop_words(s) for s in all_desc]

# %%
all_pp
# Out:
# ["add decision logic code using if-elseif-else statement c# learn branch code's execution path evaluating boolean expressions.",
#  'configure windows app use narrator speech recognition module, show use narrator custom voice input controls make app inclusive visually impaired users.',
#  'monitor windows server iaas virtual machines hybrid instances able implement azure monitor iaas virtual machines azure, implement azure monitor on-premises environments, use dependency maps.',
#  'implement windows server iaas vm network security implement windows server iaas vm network security',
#  'recognize synthesize speech learn recognize synthesize speech using azure cognitive services.',
#  'getting started microsoft cloud adoption framework azure caf getting started. use cloud adoption framework getting started guides unblock organization’s cloud adoption efforts.',
# ...

# %%
replace_invalid = {
    '-':' ',
    r'\u202': '',
    '(':'',
    ')':'',
    '/':' ',
    "'s":'',
    ',':'',
    '. ':' ',
    '`':'',
    "\'":'',
    ':':'',
    ';':'',
    '?':'',
    '--':''
}

# %%
def replace_end_fullstop(sent):
    if(sent[-1]=='.'):
        return sent[:-1]
    return sent

pre_processed = []
for sent in all_pp:
    for k in list(replace_invalid.keys()):
        sent = sent.replace(k, replace_invalid[k])
    pre_processed.append(replace_end_fullstop(sent))
    print(replace_end_fullstop(sent))
# Out:
# add decision logic code using if elseif else statement c# learn branch code execution path evaluating boolean expressions
# configure windows app use narrator speech recognition module show use narrator custom voice input controls make app inclusive visually impaired users
# monitor windows server iaas virtual machines hybrid instances able implement azure monitor iaas virtual machines azure implement azure monitor on premises environments use dependency maps
# implement windows server iaas vm network security implement windows server iaas vm network security
# recognize synthesize speech learn recognize synthesize speech using azure cognitive services
# getting started microsoft cloud adoption framework azure caf getting started use cloud adoption framework getting started guides unblock organization’s cloud adoption efforts
# choose best monitoring service visibility insight outage mitigation learn solutions give organization insight health performance cloud based applications
# ...

# %%
pre_processed
# Out:
# ['add decision logic code using if elseif else statement c# learn branch code execution path evaluating boolean expressions',
#  'configure windows app use narrator speech recognition module show use narrator custom voice input controls make app inclusive visually impaired users',
#  'monitor windows server iaas virtual machines hybrid instances able implement azure monitor iaas virtual machines azure implement azure monitor on premises environments use dependency maps',
#  'implement windows server iaas vm network security implement windows server iaas vm network security',
#  'recognize synthesize speech learn recognize synthesize speech using azure cognitive services',
#  'getting started microsoft cloud adoption framework azure caf getting started use cloud adoption framework getting started guides unblock organization’s cloud adoption efforts',
# ...

# %%
data['preprocessed'] = pre_processed

# %%
data.to_csv('pre_processed_data.csv', index=False, header=True)
